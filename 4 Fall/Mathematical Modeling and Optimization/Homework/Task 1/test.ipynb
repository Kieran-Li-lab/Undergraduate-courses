# %%
import pandas as pd

data = {
    "function": ["ackley", "branin"],
    "start": ["(-3.0, -3.0)", "(2.0, 2.0)"],
    "method": ["Powell", "Powell"],
    "x found": [
        "(-6.349111895778041e-08, 4.763125222948886e-08)",
        "(9.42477797130609, 2.475000016260335)"
    ],
    "f(x found)": [0.000000, 0.397887],
    "iterations": [1, 4],
    "time (s)": [0.0064, 0.0000]
}

df = pd.DataFrame(data)
df                                           # Jupyter 下会直接渲染
# Out:
#   function         start  method  \
# 0   ackley  (-3.0, -3.0)  Powell
# 1   branin    (2.0, 2.0)  Powell
#
#                                            x found  f(x found)  iterations  \
# 0  (-6.349111895778041e-08, 4.763125222948886e-08)    0.000000           1
# 1            (9.42477797130609, 2.475000016260335)    0.397887           4
#
#    time (s)
# 0    0.0064
# 1    0.0000
